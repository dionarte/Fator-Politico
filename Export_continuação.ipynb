# %%
import networkx as nx;

import osmnx as ox;

G = ox.graph_from_place('João Pessoa, Paraíba', network_type = 'drive');

id1 = ox.distance.nearest_nodes(G, -34.86974, -7.10056, return_dist=False);

id2 = ox.distance.nearest_nodes(G, -34.83813, -7.12331, return_dist=False);

id3 = ox.distance.nearest_nodes(G, -34.88437, -7.19891, return_dist=False);

id4 = ox.distance.nearest_nodes(G, -34.88316, -7.18404, return_dist=False);

id5 = ox.distance.nearest_nodes(G, -34.88437, -7.19891, return_dist=False);

id6 = ox.distance.nearest_nodes(G, -34.86974, -7.10056, return_dist=False);

# %%
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import earthpy as et
import pandas as pd
#import qgs as qgis

# %%
#escolas = gpd.read_file("C:\\Users/firmi/OneDrive/Documentos/escolas31985.geojson");

os.chdir(r'C:\Users\firmi\OneDrive\Documentos\Trabalho_SIG\csv')
lista = os.listdir(os.getcwd())
print(lista)

datos = pd.read_csv(lista[0],parse_dates=True,index_col=1)
datos.sort_index(inplace=True)
print(datos.head())
# Out:
# ['cache', 'caminho', 'csv_test.csv', 'rota', 'rota.shp', 'rotanova', 'rotatrajeto.cpg', 'rotatrajeto.dbf', 'rotatrajeto.prj', 'rotatrajeto.shp', 'rotatrajeto.shx']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/2075403339.py in <module>
#       5 print(lista)
#       6
# ----> 7 datos = pd.read_csv(lista[0],parse_dates=True,index_col=1)
#       8 datos.sort_index(inplace=True)
#       9 print(datos.head())
#
# ~\anaconda3\envs\ox\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#código para estudar:

# %%
id1 = ox.distance.nearest_nodes(G, -34.86974, -7.10056, return_dist=False);

id2 = ox.distance.nearest_nodes(G, -34.83813, -7.12331, return_dist=False);

id3 = ox.distance.nearest_nodes(G, -34.88437, -7.19891, return_dist=False);

id4 = ox.distance.nearest_nodes(G, -34.88316, -7.18404, return_dist=False);

id5 = ox.distance.nearest_nodes(G, -34.88437, -7.19891, return_dist=False);

id6 = ox.distance.nearest_nodes(G, -34.86974, -7.10056, return_dist=False);

#Com os IDs dos Nós, calcular a rota mais curta:


trajeto = ox.distance.shortest_path(G, id1, id2, weight='length', cpus=1);
#trajeto2 = nx.distance.k_shortest_path(G, id3, id4, weight='length', cpus=1);
#trajeto3 = nx.distance.k_shortest_path(G, id5, id6, weight='length', cpus=1);

# %%
print(trajeto);
# Out:
# [670602798, 7218056348, 914627434, 670602688, 914627445, 914627455, 670602683, 2765960112, 914627578, 914627889, 2540728293, 914627765, 7217797202, 914627728, 914627704, 914627642, 914627665, 2051903037, 2051903009, 1869443009, 670602790, 2051903044, 618516881, 618516883, 618516882, 618516872, 618516912, 618516904, 618516898, 7221488415, 7185842513, 618516847, 7185842512, 2106615024, 598927459, 598927460, 337592897, 598927452, 598927453, 598927448, 598927380, 598927367, 598927359, 598927360, 508062190, 2657589188, 598927127, 587649046, 598927147, 602379518, 3089043388, 602379493, 602377327, 595302045, 7202427106, 1869448535, 1869448536, 7202427102, 7202427107, 2538730221, 458411573, 1869448212, 587649050, 458403676, 458399039, 458409479, 458409484]

# %%
fig, ax = ox.plot.plot_graph_route(G, t, node_size=1);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/2269292908.py in <module>
# ----> 1 fig, ax = ox.plot.plot_graph_route(G, t, node_size=1);
#
# ~\anaconda3\envs\ox\lib\site-packages\osmnx\plot.py in plot_graph_route(G, route, route_color, route_linewidth, route_alpha, orig_dest_size, ax, **pg_kwargs)
#     292
#     293     # scatterplot origin and destination points (first/last nodes in route)
# --> 294     x = (G.nodes[route[0]]["x"], G.nodes[route[-1]]["x"])
#     295     y = (G.nodes[route[0]]["y"], G.nodes[route[-1]]["y"])
#     296     ax.scatter(x, y, s=orig_dest_size, c=route_color, alpha=route_alpha, edgecolor="none")
#
# TypeError: 'generator' object is not subscriptable

# %%
#origem = G.nodes[id1];
#destino = G.nodes[id2];

traj = trajeto.;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/3626491343.py in <module>
#       2 #destino = G.nodes[id2];
#       3
# ----> 4 traj = trajeto.nodes;
#
# AttributeError: 'list' object has no attribute 'nodes'

# %%
import osmapi as osm;

api = osm.OsmApi() # this instantiate the OsmApi class,
# it has many function, we will use NodeGet function.
# For more detail about it check the doc
# http://osmapi.metaodi.ch/#osmapi.OsmApi.OsmApi.NodeGet
node = api.NodeGet([trajeto])
node # will return a dict object
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/3095034495.py in <module>
# ----> 1 import osmapi as osm;
#       2
#       3 api = osm.OsmApi() # this instantiate the OsmApi class,
#       4 # it has many function, we will use NodeGet function.
#       5 # For more detail about it check the doc
#
# ModuleNotFoundError: No module named 'osmapi'

# %%
teste = ox.folium.plot_route_folium(G, trajeto, route_map=None, popup_attribute=None, tiles='cartodbpositron', zoom=1, fit_bounds=True, route_color=None, route_width=None, route_opacity=None);

teste
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import osmnx as ox
#G = ox.graph_from_place('Piedmont, CA, USA', network_type='drive')
#gdf_nodes, gdf_edges = ox.graph_to_gdfs()
#path = nx.shortest_path(G, G.nodes()[0], G.nodes()[1])
#gdf_nodes.loc[path]
import osmnx as ox
#G = ox.graph_from_place('João Pessoa, PB, BRAZIL', network_type='drive')
node_id = list(trajeto.nodes)[0]
trajeto.nodes[node_id]['x'] #lon
trajeto.nodes[node_id]['y'] #lat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/3268815646.py in <module>
#       6 import osmnx as ox
#       7 #G = ox.graph_from_place('João Pessoa, PB, BRAZIL', network_type='drive')
# ----> 8 node_id = list(trajeto.nodes)[0]
#       9 trajeto.nodes[node_id]['x'] #lon
#      10 trajeto.nodes[node_id]['y'] #lat
#
# AttributeError: 'list' object has no attribute 'nodes'

# %%
#c = c.drop(['y','x','street_count','highway'], axis=1);
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\ox\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\envs\ox\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\envs\ox\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
#ox.io.save_graph_shapefile(c, filepath=u'caminho', encoding='utf-8', directed=False)
c.to_file("rotatrajeto.shp");
c.to_file(r"C:\Users\firmi\OneDrive\Documentos\rotatrajeto.shp");

# %%
#n = len(trajeto)
#n
#teste = G.nodes[trajeto];
#teste
#gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
#c = gdf_nodes.loc[trajeto]
d = ox.graph.graph_from_point(c, dist=1000, dist_type='bbox', network_type='drive', simplify=True, retain_all=False, truncate_by_edge=False, clean_periphery=True, custom_filter=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/677120377.py in <module>
#       5 #gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
#       6 #c = gdf_nodes.loc[trajeto]
# ----> 7 d = ox.graph.graph_from_point(c, dist=1000, dist_type='bbox', network_type='drive', simplify=True, retain_all=False, truncate_by_edge=False, clean_periphery=True, custom_filter=None)
#
# ~\anaconda3\envs\ox\lib\site-packages\osmnx\graph.py in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     151
#     152     # create bounding box from center point and distance in each direction
# --> 153     north, south, east, west = utils_geo.bbox_from_point(center_point, dist)
#     154
#     155     # create a graph from the bounding box
#
# ...

# %%
import ogre;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16244/953652582.py in <module>
# ----> 1 import ogre;
#
# ModuleNotFoundError: No module named 'ogre'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16244/1408539797.py in <module>
# ----> 1 driver = osr.GetDriverByName('ESRI Shapefile');
#
# NameError: name 'osr' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19328/557123362.py in <module>
# ----> 1 G1 = ox.graph.graph_from_point(id1, dist=1000, dist_type='bbox', network_type='drive', simplify=True, retain_all=False, truncate_by_edge=False, clean_periphery=True, custom_filter=None);
#
# ~\anaconda3\envs\ox\lib\site-packages\osmnx\graph.py in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     151
#     152     # create bounding box from center point and distance in each direction
# --> 153     north, south, east, west = utils_geo.bbox_from_point(center_point, dist)
#     154
#     155     # create a graph from the bounding box
#
# ~\anaconda3\envs\ox\lib\site-packages\osmnx\utils_geo.py in bbox_from_point(point, dist, project_utm, return_crs)
#     462     """
# ...

# %%
print(G)

# %%
G
